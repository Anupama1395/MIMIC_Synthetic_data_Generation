# %%
#IMPORT ALL THE REQUIRED LIBERARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings

from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

warnings.filterwarnings('ignore')
# %matplotlib inline

# STEP 2: Fix multiprocessing issues (Windows)
os.environ["NUMBA_NUM_THREADS"] = "1"
os.environ["JOBLIB_START_METHOD"] = "spawn"

# %%
import torch

# %%
# Load the dataset
LABEVENTS = pd.read_csv("LABEVENTS.csv.gz")
print(LABEVENTS.shape)
LABEVENTS.head()
# Out:
# (27854055, 9)
#    ROW_ID  SUBJECT_ID  HADM_ID  ITEMID            CHARTTIME VALUE  VALUENUM  \
# 0     281           3      NaN   50820  2101-10-12 16:07:00  7.39      7.39
# 1     282           3      NaN   50800  2101-10-12 18:17:00   ART       NaN
# 2     283           3      NaN   50802  2101-10-12 18:17:00    -1     -1.00
# 3     284           3      NaN   50804  2101-10-12 18:17:00    22     22.00
# 4     285           3      NaN   50808  2101-10-12 18:17:00  0.93      0.93
#
#   VALUEUOM      FLAG
# 0    units       NaN
# 1      NaN       NaN
# 2    mEq/L       NaN
# 3    mEq/L       NaN
# 4   mmol/L  abnormal

# %%
LABEVENTS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27854055 entries, 0 to 27854054
# Data columns (total 9 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ROW_ID      int64
#  1   SUBJECT_ID  int64
#  2   HADM_ID     float64
#  3   ITEMID      int64
#  4   CHARTTIME   object
#  5   VALUE       object
#  6   VALUENUM    float64
#  7   VALUEUOM    object
#  8   FLAG        object
# dtypes: float64(2), int64(3), object(4)
# memory usage: 1.9+ GB

# %%
# Check missing values
missing = LABEVENTS.isnull().sum()
print(missing[missing > 0])
# Out:
# HADM_ID      5609021
# VALUE           1349
# VALUENUM     2921220
# VALUEUOM     3100249
# FLAG        18009889
# dtype: int64

# %%
LABEVENTS.shape
# Out:
# (27854055, 9)

# %%
# Drop rows with missing key values (adjust as needed)
required_cols = ['ROW_ID']
LABEVENTS_cleaned = LABEVENTS.dropna(subset=required_cols)

# %%
LABEVENTS_cleaned.fillna({
    'VALUENUM': np.nan,
    'VALUEUOM': 'UNKNOWN',
    'FLAG': 'UNKNOWN',
    'HADM_ID': -1
}, inplace=True)

# %%
# Encode categorical columns
cat_cols = LABEVENTS_cleaned.select_dtypes(include='object').columns
for col in cat_cols:
    LABEVENTS_cleaned[col] = LABEVENTS_cleaned[col].astype('category').cat.codes

# %%
# Drop duplicates
LABEVENTS.drop_duplicates(inplace=True)

# %%
# drop rows where essential columns are missing
essential_cols = ['CHARTTIME', 'VALUE', 'VALUENUM','VALUEUOM','FLAG'] 
LABEVENTS_cleaned = LABEVENTS.dropna(subset=essential_cols)

# %%
# Save cleaned file
LABEVENTS_cleaned.to_csv("LABEVENTS_cleaned.csv", index=False)

# %%
# !pip install sdv
# Out:
# Requirement already satisfied: sdv in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (1.24.1)
# Requirement already satisfied: boto3<2.0.0,>=1.28 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (1.39.4)
# Requirement already satisfied: botocore<2.0.0,>=1.31 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (1.39.4)
# Requirement already satisfied: cloudpickle>=2.1.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (3.1.1)
# Requirement already satisfied: graphviz>=0.13.2 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (0.21)
# Requirement already satisfied: numpy>=1.26.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (2.3.1)
# Requirement already satisfied: pandas>=2.1.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (2.3.1)
# Requirement already satisfied: tqdm>=4.29 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (4.67.1)
# Requirement already satisfied: copulas>=0.12.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (0.12.3)
# Requirement already satisfied: ctgan>=0.11.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (0.11.0)
# Requirement already satisfied: deepecho>=0.7.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (0.7.0)
# Requirement already satisfied: rdt>=1.17.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (1.17.1)
# Requirement already satisfied: sdmetrics>=0.21.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (0.21.0)
# Requirement already satisfied: platformdirs>=4.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (4.3.8)
# Requirement already satisfied: pyyaml>=6.0.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sdv) (6.0.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from boto3<2.0.0,>=1.28->sdv) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from boto3<2.0.0,>=1.28->sdv) (0.13.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from botocore<2.0.0,>=1.31->sdv) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from botocore<2.0.0,>=1.31->sdv) (2.5.0)
# Requirement already satisfied: plotly>=5.10.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from copulas>=0.12.1->sdv) (6.2.0)
# Requirement already satisfied: scipy>=1.12.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from copulas>=0.12.1->sdv) (1.16.0)
# Requirement already satisfied: torch>=2.2.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from ctgan>=0.11.0->sdv) (2.7.1)
# Requirement already satisfied: pytz>=2020.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from pandas>=2.1.1->sdv) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from pandas>=2.1.1->sdv) (2025.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from rdt>=1.17.0->sdv) (1.7.0)
# Requirement already satisfied: Faker>=17 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from rdt>=1.17.0->sdv) (37.4.2)
# Requirement already satisfied: narwhals>=1.15.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (1.47.0)
# Requirement already satisfied: packaging in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from plotly>=5.10.0->copulas>=0.12.1->sdv) (25.0)
# Requirement already satisfied: six>=1.5 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<2.0.0,>=1.31->sdv) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from scikit-learn>=1.3.1->rdt>=1.17.0->sdv) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from scikit-learn>=1.3.1->rdt>=1.17.0->sdv) (3.6.0)
# Requirement already satisfied: filelock in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (4.14.1)
# Requirement already satisfied: setuptools in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (1.14.0)
# Requirement already satisfied: networkx in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (3.5)
# Requirement already satisfied: jinja2 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (3.1.6)
# Requirement already satisfied: fsspec in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (2025.7.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from torch>=2.2.0->ctgan>=0.11.0->sdv) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.2.0->ctgan>=0.11.0->sdv) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages (from jinja2->torch>=2.2.0->ctgan>=0.11.0->sdv) (3.0.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Imports
import pandas as pd
from sdv.single_table import CTGANSynthesizer
from sdv.metadata import SingleTableMetadata

LABEVENTS_cleaned = pd.read_csv("LABEVENTS_cleaned.csv")

#  Generate metadata for SINGLE TABLE
metadata = SingleTableMetadata()
metadata.detect_from_dataframe(LABEVENTS_cleaned)

# Initialize synthesizer (no enforce_minimal in this version)
synthesizer = CTGANSynthesizer(
    metadata=metadata,
    epochs=30,
)

#  Fit the synthesizer to the data
synthesizer.fit(LABEVENTS_cleaned)

synthetic_same_size = synthesizer.sample(num_rows=len(LABEVENTS_cleaned))
synthetic_data = synthesizer.sample(num_rows=1000)

#  Save synthetic data
synthetic_data.to_csv("synthetic_LABEVENTS.csv", index=False)

# Preview
synthetic_data.head()
# Out:
# ---------------------------------------------------------------------------
# _RemoteTraceback                          Traceback (most recent call last)
# _RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 490, in _process_worker
#     r = call_item()
#         ^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py", line 291, in __call__
#     return self.fn(*self.args, **self.kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py", line 607, in __call__
#     return [func(*args, **kwargs) for func, args, kwargs in self.items]
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/ctgan/data_transformer.py", line 138, in _transform_discrete
#     return ohe.transform(data).to_numpy()
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/rdt/transformers/base.py", line 57, in wrapper
#     return function(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/rdt/transformers/base.py", line 424, in transform
#     transformed_data = self._transform(columns_data)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/rdt/transformers/categorical.py", line 682, in _transform
#     return self._transform_helper(data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/ehr/Desktop/anupama/.venv/lib/python3.12/site-packages/rdt/transformers/categorical.py", line 650, in _transform_helper
#     array = (coded == dummies).astype(int)
#              ^^^^^^^^^^^^^^^^
# numpy._core._exceptions._ArrayMemoryError: Unable to allocate 516. GiB for an array with shape (9582656, 57786) and data type bool
# """
#
# The above exception was the direct cause of the following exception:
#
# MemoryError                               Traceback (most recent call last)
# Cell In[30], line 19
#      13 synthesizer = CTGANSynthesizer(
#      14     metadata=metadata,
#      15     epochs=30,
#      16 )
#      18 #  Fit the synthesizer to the data
# ---> 19 synthesizer.fit(LABEVENTS_cleaned)
#      21 synthetic_same_size = synthesizer.sample(num_rows=len(LABEVENTS_cleaned))
#      22 synthetic_data = synthesizer.sample(num_rows=1000)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/sdv/single_table/base.py:667, in BaseSynthesizer.fit(self, data)
#     665 is_converted = self._store_and_convert_original_cols(data)
#     666 processed_data = self.preprocess(data)
# --> 667 self.fit_processed_data(processed_data)
#     668 if is_converted:
#     669     data.columns = self._original_columns
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/sdv/single_table/base.py:636, in BaseSynthesizer.fit_processed_data(self, processed_data)
#     634 check_synthesizer_version(self, is_fit_method=True, compare_operator=operator.lt)
#     635 if not processed_data.empty:
# --> 636     self._fit(processed_data)
#     638 self._fitted = True
#     639 self._fitted_date = datetime.datetime.today().strftime('%Y-%m-%d')
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/sdv/single_table/ctgan.py:303, in CTGANSynthesizer._fit(self, processed_data)
#     301 with warnings.catch_warnings():
#     302     warnings.filterwarnings('ignore', message='.*Attempting to run cuBLAS.*')
# --> 303     self._model.fit(processed_data, discrete_columns=discrete_columns)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/ctgan/synthesizers/base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/ctgan/synthesizers/ctgan.py:348, in CTGAN.fit(self, train_data, discrete_columns, epochs)
#     345 self._transformer = DataTransformer()
#     346 self._transformer.fit(train_data, discrete_columns)
# --> 348 train_data = self._transformer.transform(train_data)
#     350 self._data_sampler = DataSampler(
#     351     train_data, self._transformer.output_info_list, self._log_frequency
#     352 )
#     354 data_dim = self._transformer.output_dimensions
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/ctgan/data_transformer.py:187, in DataTransformer.transform(self, raw_data)
#     183     column_data_list = self._synchronous_transform(
#     184         raw_data, self._column_transform_info_list
#     185     )
#     186 else:
# --> 187     column_data_list = self._parallel_transform(raw_data, self._column_transform_info_list)
#     189 return np.concatenate(column_data_list, axis=1).astype(float)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/ctgan/data_transformer.py:172, in DataTransformer._parallel_transform(self, raw_data, column_transform_info_list)
#     169         process = delayed(self._transform_discrete)(column_transform_info, data)
#     170     processes.append(process)
# --> 172 return Parallel(n_jobs=-1)(processes)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py:1784, in Parallel._retrieve(self)
#    1778 while self._wait_retrieval():
#    1779     # If the callback thread of a worker has signaled that its task
#    1780     # triggered an exception, or if the retrieval loop has raised an
#    1781     # exception (e.g. `GeneratorExit`), exit the loop and surface the
#    1782     # worker traceback.
#    1783     if self._aborting:
# -> 1784         self._raise_error_fast()
#    1785         break
#    1787     nb_jobs = len(self._jobs)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py:1859, in Parallel._raise_error_fast(self)
#    1855 # If this error job exists, immediately raise the error by
#    1856 # calling get_result. This job might not exists if abort has been
#    1857 # called directly or if the generator is gc'ed.
#    1858 if error_job is not None:
# -> 1859     error_job.get_result(self.timeout)
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py:758, in BatchCompletionCallBack.get_result(self, timeout)
#     752 backend = self.parallel._backend
#     754 if backend.supports_retrieve_callback:
#     755     # We assume that the result has already been retrieved by the
#     756     # callback thread, and is stored internally. It's just waiting to
#     757     # be returned.
# --> 758     return self._return_or_raise()
#     760 # For other backends, the main thread needs to run the retrieval step.
#     761 try:
#
# File ~/Desktop/anupama/.venv/lib/python3.12/site-packages/joblib/parallel.py:773, in BatchCompletionCallBack._return_or_raise(self)
#     771 try:
#     772     if self.status == TASK_ERROR:
# --> 773         raise self._result
#     774     return self._result
#     775 finally:
#
# MemoryError: Unable to allocate 516. GiB for an array with shape (9582656, 57786) and data type bool

# %%
print("Synthesizer fitted:", synthesizer._fitted)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Example: Compare distributions of a categorical column
column = 'FLAG'

plt.figure(figsize=(10,5))

# Real data
sns.countplot(x=column, data=LABEVENTS_cleaned, color='blue', label='Real', alpha=0.5)

# Synthetic data
sns.countplot(x=column, data=synthetic_data, color='red', label='Synthetic', alpha=0.5)

plt.legend()
plt.title(f"Real vs Synthetic: {column}")
plt.xticks(rotation=45)
plt.show()

# %%
#  Load synthetic dataset
import pandas as pd
import os
synthetic = pd.read_csv("synthetic_LABEVENTS.csv")

#   Setup for evaluation
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Choose features and target
features = ['ITEMID','CHARTTIME','VALUE']
target = 'FLAG'

# Ensure encoding consistency
for col in features:
    LABEVENTS_cleaned[col] = LABEVENTS_cleaned[col].astype('category').cat.codes
    synthetic_data[col] = synthetic_data[col].astype('category').cat.codes

# Real data model
X_real = LABEVENTS_cleaned[features]
y_real = LABEVENTS_cleaned[target]
Xr_train, Xr_test, yr_train, yr_test = train_test_split(X_real, y_real, test_size=0.3)

model_real = RandomForestClassifier()
model_real.fit(Xr_train, yr_train)
real_acc = accuracy_score(yr_test, model_real.predict(Xr_test))

# Synthetic data model
X_syn = synthetic_data[features]
y_syn = synthetic_data[target]
Xs_train, Xs_test, ys_train, ys_test = train_test_split(X_syn, y_syn, test_size=0.3)

model_syn = RandomForestClassifier()
model_syn.fit(Xs_train, ys_train)
syn_acc = accuracy_score(ys_test, model_syn.predict(Xs_test))

print(f" Model accuracy on real data:     {real_acc:.2f}")
print(f" Model accuracy on synthetic data:  {syn_acc:.2f}")

# %%
#  Import TVAESynthesizer
from sdv.single_table import TVAESynthesizer

#  Initialize VAE synthesizer
vae_synthesizer = TVAESynthesizer(
    metadata=metadata,
    epochs=10
)

# Fit the VAE synthesizer
vae_synthesizer.fit(LABEVENTS_cleaned)

#  Sample synthetic data using VAE
synthetic_data_vae = vae_synthesizer.sample(num_rows=1000)

#  Save VAE synthetic data
synthetic_data_vae.to_csv('synthetic_LABEVENTS_vae.csv', index=False)

#  Preview VAE synthetic data
synthetic_data_vae.head()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Load your synthetic data generated from VAE
synthetic_vae = pd.read_csv('synthetic_LABEVENTS_vae.csv')

# Preprocessing: convert categorical columns to numeric codes
features = ['ITEMID','CHARTTIME','VALUE']
target = 'FLAG'

# Make sure all datasets are prepared
for col in features:
    LABEVENTS_cleaned[col] = LABEVENTS_cleaned[col].astype('category').cat.codes
    synthetic_vae[col] = synthetic_vae[col].astype('category').cat.codes

# Real data model (already trained if you want, but re-training to be safe)
X_real = LABEVENTS_cleaned[features]
y_real = LABEVENTS_cleaned[target]
Xr_train, Xr_test, yr_train, yr_test = train_test_split(X_real, y_real, test_size=0.3, random_state=42)

model_real = RandomForestClassifier(random_state=42)
model_real.fit(Xr_train, yr_train)
real_acc = accuracy_score(yr_test, model_real.predict(Xr_test))

# VAE Synthetic data model
X_vae = synthetic_vae[features]
y_vae = synthetic_vae[target]
Xv_train, Xv_test, yv_train, yv_test = train_test_split(X_vae, y_vae, test_size=0.3, random_state=42)

model_vae = RandomForestClassifier(random_state=42)
model_vae.fit(Xv_train, yv_train)
vae_acc = accuracy_score(yv_test, model_vae.predict(Xv_test))

# Show results
print(f" Model accuracy on real data:       {real_acc:.2f}")
print(f" Model accuracy on VAE synthetic data: {vae_acc:.2f}")

# %%
import matplotlib.pyplot as plt

#  accuracy values
# These are from your previous results:
real_acc = real_acc          # Accuracy on real data using real training
vae_acc = vae_acc           # Accuracy on synthetic VAE data
gan_acc = syn_acc           # Accuracy on synthetic GAN (CTGAN) data

# Prepare bar chart data
labels = ['Real Data (Original)', 'CTGAN (Synthetic)', 'TVAE (Synthetic)']
accuracy_scores = [real_acc, gan_acc, vae_acc]

# Plotting
plt.figure(figsize=(10, 6))
bars = plt.bar(labels, accuracy_scores, color=['skyblue', 'orange', 'green'])

#  chart elements
plt.title('Model Accuracy Comparison: Real vs CTGAN vs TVAE', fontsize=14, fontweight='bold')
plt.ylabel('Accuracy Score')
plt.ylim(0.2, 1.5)
plt.grid(axis='y', linestyle='--', alpha=0.4)

# Annotate bars
for i, acc in enumerate(accuracy_scores):
    plt.text(i, acc + 0.01, f"{acc:.2f}", ha='center', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()
